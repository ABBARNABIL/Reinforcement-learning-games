# %%
import gym
from gym.utils.play import play

env = gym.make('Pong-v4')
env.reset()
play(env, zoom=3, fps=12)

env.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15620/185621872.py in <module>
# ----> 1 import gym
#       2 from gym.utils.play import play
#       3
#       4 env = gym.make('Pong-v4')
#       5 env.reset()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\gym\__init__.py in <module>
#      11 )
#      12 from gym.spaces import Space
# ---> 13 from gym.envs import make, spec, register
#      14 from gym import logger
#      15 from gym import vector
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\gym\envs\__init__.py in <module>
#       8
#       9 # Hook to load plugins from entry points
# ---> 10 _load_env_plugins()
#      11
#      12
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\gym\envs\registration.py in load_env_plugins(entry_point)
#     274
#     275         with context:
# --> 276             fn = plugin.load()
#     277             try:
#     278                 fn()
#
# ~\anaconda3\lib\importlib\metadata.py in load(self)
#      75         """
#      76         match = self.pattern.match(self.value)
# ---> 77         module = import_module(match.group('module'))
#      78         attrs = filter(None, (match.group('attr') or '').split('.'))
#      79         return functools.reduce(getattr, attrs, module)
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ale_py\gym.py in <module>
#       3 from gym.envs.registration import register
#       4
# ----> 5 from ale_py.roms.utils import rom_name_to_id, rom_id_to_name
#       6
#       7
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ale_py\roms\__init__.py in <module>
#      92
#      93
# ---> 94 _RESOLVED_ROMS = _resolve_roms()
#      95
#      96 # Update module
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ale_py\roms\__init__.py in _resolve_roms()
#      44         try:
#      45             # Resolve supported / unsupported roms
# ---> 46             supported, unsupported = package.resolve()
#      47
#      48             # We'll now get the update delta. The reason for this is two fold:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ale_py\roms\utils.py in resolve(self)
#      58         # Iterate over all ROMs in the specified package
#      59         for resource in filter(
# ---> 60             lambda file: file.suffix == ".bin", resources.files(self.package).iterdir()
#      61         ):
#      62             resolved = resource.resolve()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\importlib_resources\_common.py in files(package)
#      20     Get a Traversable resource from a package
#      21     """
# ---> 22     return from_package(get_package(package))
#      23
#      24
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\importlib_resources\_common.py in get_package(package)
#      51     Raise an exception if the resolved module is not a package.
#      52     """
# ---> 53     resolved = resolve(package)
#      54     if wrap_spec(resolved).submodule_search_locations is None:
#      55         raise TypeError(f'{package!r} is not a package')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\importlib_resources\_common.py in resolve(cand)
#      42 def resolve(cand):
#      43     # type: (Package) -> types.ModuleType
# ---> 44     return cand if isinstance(cand, types.ModuleType) else importlib.import_module(cand)
#      45
#      46
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\atari_py\__init__.py in <module>
# ----> 1 from .ale_python_interface import *
#       2 from .games import get_game_path, list_games
#       3
#       4 # default to only logging errors
#       5 ALEInterface.setLoggerMode(ALEInterface.Logger.Error)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\atari_py\ale_python_interface.py in <module>
#      15                                             'ale_interface/libale_c.so'))
#      16 else:
# ---> 17     ale_lib = cdll.LoadLibrary(os.path.join(os.path.dirname(__file__),
#      18                                             'ale_interface/ale_c.dll'))
#      19
#
# ~\anaconda3\lib\ctypes\__init__.py in LoadLibrary(self, name)
#     458
#     459     def LoadLibrary(self, name):
# --> 460         return self._dlltype(name)
#     461
#     462     __class_getitem__ = classmethod(_types.GenericAlias)
#
# ~\anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     380
#     381         if handle is None:
# --> 382             self._handle = _dlopen(self._name, mode)
#     383         else:
#     384             self._handle = handle
#
# FileNotFoundError: Could not find module 'C:\Users\nabil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\atari_py\ale_interface\ale_c.dll' (or one of its dependencies). Try using the full path with constructor syntax.

# %%
def mycallback(obs_t, obs_tp1, action, rew, done, info):
 print("action = ", action, " reward = ", rew, "done = ", done)

gym.utils.play.play(env, zoom=3, fps=12, callback=mycallback)
